# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1,9))

# %%
from random import randrange

# %%
notas_matematicas = [randrange(1,11) for i in range(8)]

# %%
y = [randrange(1,11) for i in range(8)]

# %%
plt.plot(x, y, marker='o')
plt.title('Notas matematica')
plt.xlabel('provas')
plt.ylabel('Notas')
plt.show()
